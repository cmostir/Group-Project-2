# %% [markdown]
# <a href="https://colab.research.google.com/github/cmostir/Group-Project-2/blob/main/GroupAssignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Group Assignment 2

# %% [markdown]
# ## Description of Model:

# %% [markdown]
#   We chose to redesign the layout of our diagram conceptually by reorganizing the tables and data within the tables. On the left, we put more "customer-based" tables, like the customer themselves, the customer's food, and the delivery to the customer. On the right, we put tables that were more "company based," like the staff, order, and payment.
#   This not only makes it easier to logically separate entities, but it also makes it easier to understand how they interact with one another. By setting customer-based tables across from business-based tables, many of the interactions now run horizontally as well as vertically, rather than having a mix of diagonals and crossing lines.
#   We also wanted to keep the ER Diagram somewhat similar to last time, so we didn't have to change too many of the attributes or interactions within the table. Some shifting was necessary to get the diagram into first normal form, but we were still able to keep the design relatively simple and straightforward while we reorganized. We were able to weed out some of the redundancies we saw that we had previously, making the project look a lot cleaner as a whole. We set up the diagram in a fashion that would allow it to easily progress past first normal form (possibly straight into second normal form), without having to alter the tables so much that the design is completely altered. We believe it's important to slowly progress rather than make large changes at once, because when you make large changes, you risk losing some of the purpose of the model's creation. Each model can be a little different, so trying to fit it into one logical concept doesn't seem realistic or reasonable. Putting in slight changes as the tables are normalized helps keep some of the intentions we had when first creating the model.

# %% [markdown]
# ## Image of Model:

# %% [markdown]
# ![Group assignment 2.png](data:image/png;base64,...)
